# %%
import os
import io
from typing import List, Dict, Any

import PyPDF2
from PIL import Image
import pytesseract
import docx
from dotenv import load_dotenv

# LangChain public interfaces
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from langchain.callbacks import get_openai_callback

# Import your persona prompts explicitly
from prompts import HEOR_modeler, Clinician, Health_policy_maker, Market_access_professional, Statistician, Layman

# Load environment variables
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %%
class ChatHistory:
    def __init__(self):
        self.history: List[Dict[str, str]] = []

    def add_message(self, role: str, content: str):
        self.history.append({"role": role, "content": content})

    def get_messages(self) -> List[Dict[str, str]]:
        return self.history

    def clear_history(self):
        self.history = []

    def set_parameters(self, profession: str, max_words: int, engine: str, temperature: float, max_tokens: int):
        self.profession = profession
        self.max_words = max_words
        self.engine = engine
        self.temperature = temperature
        self.max_tokens = max_tokens

# %%
def generate_response(
    question: str,
    profession: str,
    max_words: int,
    api_key: str,
    engine: str,
    temperature: float,
    max_tokens: int,
    chat_history: ChatHistory = None
) -> tuple:
    """Generate a response using OpenAI's API with optional chat history."""
    # Select the right system prompt
    if profession == 'HEOR modeler':
        system_prompt = HEOR_modeler
    elif profession == 'Clinician':
        system_prompt = Clinician
    elif profession == 'Health policy maker':
        system_prompt = Health_policy_maker
    elif profession == 'Market access professional':
        system_prompt = Market_access_professional
    elif profession == 'Statistician':
        system_prompt = Statistician
    else:
        system_prompt = Layman

    # Assemble messages
    messages = [("system", system_prompt)]
    if chat_history and chat_history.history:
        for msg in chat_history.history:
            messages.append((msg["role"], msg["content"]))
    messages.append(("user", "Statement: {question}"))  

    # Build prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Initialize the LLM
    llm = ChatOpenAI(
        model_name=engine,
        temperature=temperature,
        max_tokens=max_tokens,
        openai_api_key=api_key
    )

    # Chain prompt + LLM
    chain = LLMChain(llm=llm, prompt=prompt)

    # Invoke and capture usage
    with get_openai_callback() as cb:
        answer = chain.predict(question=question)
        if chat_history:
            chat_history.add_message("assistant", answer)
        return answer, cb

# %%
# File-processing helpers (unchanged)
def extract_text_from_pdf(file_path):
    with open(file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        return "".join(page.extract_text() or "" for page in reader.pages)


# def extract_text_from_image(file_path):
#     img = Image.open(file_path)
#     return pytesseract.image_to_string(img)


def extract_text_from_docx(file_path):
    doc = docx.Document(file_path)
    return "\n".join(p.text for p in doc.paragraphs)


def process_file(file_path):
    lp = file_path.lower()
    if lp.endswith('.pdf'):
        return extract_text_from_pdf(file_path)
    if lp.endswith(('.png', '.jpg', '.jpeg')):
        return extract_text_from_image(file_path)
    if lp.endswith('.docx'):
        return extract_text_from_docx(file_path)
    return None

# %%
# Example usage
if __name__ == "__main__":
    question = "What is cost-effectiveness analysis?"
    profession = "Market access professional"
    max_words = 2000
    engine = "gpt-4.1"
    temperature = 0.7
    max_tokens = int(max_words * 5)

    history = ChatHistory()
    history.set_parameters(profession, max_words, engine, temperature, max_tokens)

    if not api_key:
        print("Please set your OpenAI API key in the .env file.")
        exit(1)

    # First query
    resp, cb = generate_response(
        question, profession, max_words, api_key,
        engine, temperature, max_tokens, history
    )
    print("Response:", resp)
    print(f"Tokens used: prompt={cb.prompt_tokens}, completion={cb.completion_tokens}, total={cb.total_tokens}")
# Out:
# Response: **Interpretation for Market Access Professionals (without HEOR background):**
#
# Cost-effectiveness analysis (CEA) is a tool used to help decision-makers—like payers and health authorities—figure out if a new medicine or health technology provides good value for the money compared to what’s already available.
#
# **Think about CEA as a way to answer the question:**
# *“If we spend money on this new treatment, what do we get in return, and is it worth it compared to other options?”*
#
# Here’s how it works in practical terms:
#
# - **Comparing Costs and Benefits:**
#   CEA compares the extra cost of a new product (such as a new cancer drug) to the extra health benefits it provides. The health benefits are usually measured in terms of how much it improves patients’ lives—like helping them live longer or have a better quality of life.
#
# - **Common Outcome – The “Cost per QALY”:**
#   One of the most common ways results are reported is as a “cost per QALY” (Quality-Adjusted Life Year). This means: for every extra year of good-quality life the treatment provides, how much does it cost? For example, if Drug A costs $50,000 more than Drug B but gives patients one extra year of good-quality life, the cost-effectiveness ratio would be $50,000 per QALY.
#
# - **Why Does This Matter for Market Access?**
#   When trying to get a product reimbursed or included in national formularies, payers often want to see this kind of analysis. It helps them decide if a product is “worth it” and to prioritize spending on treatments that deliver the most health benefit for the money.
#
# - **Example in Market Access:**
#   Imagine you are preparing a submission to NICE in the UK. They will expect to see a cost-effectiveness analysis to support your product. If your product’s cost per QALY is below a certain threshold (e.g., £30,000 per QALY), it is more likely to be recommended for reimbursement.
#
# In summary, **cost-effectiveness analysis helps us make the case that our product not only works, but delivers good value compared to other options.** This is crucial for getting payers and HTA agencies on board, and ultimately securing patient access.
# Tokens used: prompt=312, completion=473, total=785

# %%
follow_up = "Can you explain that in more detail?"
history.add_message("user", follow_up)
resp, cb = generate_response(
        follow_up, profession, max_words, api_key,
        engine, temperature, max_tokens, history
    )
print("Follow-up:", resp)
# Out:
# Follow-up: Absolutely! Let’s go into more detail, still using simple language and analogies.
#
# ---
#
# ### What is Cost-Effectiveness Analysis (CEA)?
#
# **Cost-effectiveness analysis** is a way to compare different healthcare treatments or programs to see which one gives us the most health benefit for the money we spend. It helps people who make decisions in healthcare (like governments, insurance companies, or hospitals) decide where to spend their limited budget.
#
# ---
#
# ### A Simple Analogy: Fixing Your Car
#
# Imagine you have a car with a broken part. You go to two mechanics:
#
# - **Mechanic A** says they can fix your car for $100, and it will last for 1 year.
# - **Mechanic B** says they can fix your car for $150, and it will last for 3 years.
#
# Which repair should you choose?
#
# You want to know not just the price, but also how long the fix will last. So you compare the cost for each year your car will run:
#
# - Mechanic A: $100 ÷ 1 year = $100 per year
# - Mechanic B: $150 ÷ 3 years = $50 per year
#
# **Mechanic B is more cost-effective** because you get more “working car years” for each dollar spent.
#
# ---
#
# ### Applying This to Healthcare
#
# In healthcare, instead of “car years,” we are often looking at things like:
#
# - How many people get better?
# - How many years of healthy life does a treatment add?
# - How much does a treatment reduce pain or symptoms?
#
# Let’s use a made-up example with a medicine for high blood pressure:
#
# - **Medicine A**: Costs $500 per year, and keeps 1 out of 10 people from having a heart attack.
# - **Medicine B**: Costs $1,000 per year, and keeps 3 out of 10 people from having a heart attack.
#
# Now let’s see what you get for your money:
#
# - Medicine A: $500 to prevent 1 heart attack.
# - Medicine B: $1,000 to prevent 3 heart attacks ($333 per heart attack prevented).
#
# So, **Medicine B is more cost-effective** because you spend less per heart attack prevented, even though the medicine costs more overall.
#
# ---
#
# ### What About “Quality of Life”?
#
# Sometimes treatments help people live longer, but sometimes they also help people live better (less pain, more ability to do things). In CEA, experts often use a measure called “quality-adjusted life years” (QALYs). You can think of this as combining both **how long** and **how well** people live.
#
# - If a treatment gives you 1 extra year of life in perfect health, that’s 1 QALY.
# - If it gives you 2 extra years, but only at half normal health, that’s also 1 QALY (2 years × 0.5 quality).
#
# CEA often looks at **cost per QALY**—how much money does it take to give someone one extra year of good-quality life?
#
# ---
#
# ### Why Is This Important?
#
# Healthcare budgets are limited. There isn’t enough money to pay for every possible treatment for every person. Cost-effectiveness analysis helps decision makers:
#
# - **Prioritize** the treatments that do the most good for the least money.
# - **Avoid waste**—not spending a lot on treatments that don’t help much.
# - **Be fair**—so everyone gets the best possible care for the resources available.
#
# ---
#
# ### In Summary
#
# Think of CEA as **shopping for the best value**—not just the lowest price, but the best results for each dollar spent.
# It helps make sure healthcare money is spent in a way that helps the most people, in the best ways possible.
#
# If you want a more specific example or have questions about certain words, let me know!

# %%
  # File processing example
file_path = r"C:\Users\HananIrfan\OneDrive - ConnectHEOR\Desktop\Learning and Development\Fw_ Readings_ Basics of HEOR\What_are_health_util.pdf"
text = process_file(file_path)
if text:
        # Add the file's extracted text as a user message
        history.add_message("user", text)
        resp, cb = generate_response(
            text, profession, max_words, api_key,
            engine, temperature, max_tokens, history
        )
        print("From file:", resp)
else:
        print("No text extracted from file.")
# Out:
# From file: Absolutely! I’ll explain the statement in simple, layman’s terms using analogies and examples.
#
# ---
#
# ## What Are Health Utilities?
#
# **Imagine you’re rating how good or bad different health situations are, a bit like giving a movie a score out of 10.**
# But here, instead of 1 to 10, we use a scale from 0 to 1:
# - **1** means you feel as good as possible (perfect health).
# - **0** means the worst possible health (equivalent to being dead).
#
# These scores are called **utilities**. They help us put a number on how “good” or “bad” a particular health state is, based on what people prefer.
#
# ---
#
# ## Step 1: Define Health States
#
# First, you have to describe different health situations (“health states”).
# For example:
# - Living with mild pain
# - Needing help to walk
# - Having trouble breathing
#
# Each health state is like describing a different “scene” in a movie about health. You need to be specific, like: “Can walk, but with pain; needs help with daily tasks; feels tired most days.”
#
# ---
#
# ## Step 2: Value Those Health States
#
# Now, you ask people: “How good or bad does this health state feel to you, compared to perfect health or death?”
# There are two main ways to get these scores:
#
# ### A) **Direct Methods** (asking people directly)
# Examples:
# - **Standard Gamble (SG):** Like asking, “Would you rather live with this health problem, or take a risky chance: maybe you get perfect health, or maybe you die?” You adjust the chance until the person can’t decide which is better.
# - **Time Trade-Off (TTO):** “Would you rather live 10 years with this health problem, or fewer years in perfect health?” You see how many years in perfect health is “worth” 10 years with the health problem.
# - **Visual Analogue Scale (VAS):** Give people a line from 0 (worst) to 100 (best), and ask them to mark how they feel about the health state.
#
# ### B) **Indirect Methods** (using questionnaires)
# There are special surveys (like EQ-5D, SF-6D, HUI) that ask about everyday health problems (walking, pain, mood). People fill them out, and their answers are used to look up a utility score from a big database.
#
# ---
#
# ## Why Do We Do This?
#
# **Utilities are used in something called “Quality-Adjusted Life Years” (QALYs).**
#
# Let’s use an example:
# - If a treatment gives you 8 years of life in perfect health, that’s 8 QALYs (8 × 1).
# - If you get 8 years with a health problem scored at 0.5, that’s 4 QALYs (8 × 0.5).
#
# Comparing QALYs helps doctors and governments decide which treatments give the best “bang for the buck” (best health for the money).
#
# ---
#
# ## Why Is This Important?
#
# Imagine you’re running a hospital with limited money. Utilities and QALYs help you decide:
# - Should we pay for a new drug that gives people slightly better health, or use that money for something else?
# - Which treatment makes people feel better, not just live longer?
#
# It’s like using ratings to decide which movies to buy for a school—if you only have money for a few, you want those that make everyone happiest.
#
# ---
#
# ## In Summary
#
# - **Health utilities** are like scores for different health situations, based on how people feel about them.
# - We get these scores by directly asking people, or by using special surveys.
# - These scores help us compare treatments and use healthcare money in ways that help people the most.
#
# If you want a specific example or more details on any method, just ask!

# %%
follow_up = "I didn't understand the scene in a movie analogy. Please elaborate."
history.add_message("user", follow_up)
resp, cb = generate_response(
        follow_up, profession, max_words, api_key,
        engine, temperature, max_tokens, history
    )
print("Follow-up:", resp)
# Out:
# Follow-up: Of course! Let’s look at the “scene in a movie” analogy in more detail, step by step.
#
# ---
#
# ### Step 1: Imagine a Movie About Health
#
# Think about your favorite movie. Every movie is made up of different scenes, and each scene shows the characters in a certain situation—maybe they’re happy, sad, in danger, or relaxing.
#
# Now, **imagine a movie where each scene shows a person in a different health situation**. For example:
# - In one scene, the character is running and playing with friends (perfect health).
# - In another scene, the character is walking slowly because of knee pain.
# - In another, the character needs help getting dressed and feels tired all the time.
#
# Each of these scenes is like a different “health state” in real life.
#
# ---
#
# ### Step 2: Rating the Scenes
#
# Suppose you’re a movie critic, and your job is to rate each scene based on how enjoyable or good you think it is for the character.
# - The scene where the character is running and playing might get a **10 out of 10** (or 1 on the health utility scale).
# - The scene where the character can walk but is in pain might get a **5 out of 10** (or 0.5 on the health utility scale).
# - The scene where the character needs help with everything, feels tired, and can’t do what they want might get a **2 out of 10** (or 0.2 on the health utility scale).
#
# **These ratings are like “utilities” in health economics.**
# They show how good or bad each health state (scene) feels to you.
#
# ---
#
# ### Step 3: Why Describe Health States Like Scenes?
#
# Just like a movie scene includes details (location, what characters are doing, how they feel), a health state description includes details like:
# - Can the person walk?
# - Do they feel pain?
# - Can they take care of themselves?
# - Are they happy or sad?
#
# **Describing health states like scenes helps people imagine what it would be like to live in that situation and give it a score.**
#
# ---
#
# ### Step 4: Why Use These Scores?
#
# - We use these scores to compare treatments, just like you might compare different scenes or movies.
# - If a treatment helps people move from a “bad scene” to a “better scene,” we can measure how much better it makes their lives.
#
# ---
#
# **In summary:**
# Each “scene” in the movie analogy is a different health situation someone might experience. We “rate” these scenes to figure out how good or bad each one is. These ratings help doctors and decision-makers compare different treatments in a fair and understandable way.
#
# If you’d like, I can give you a concrete example using a made-up movie and specific scenes!

# %%
 #to print entire chat history
print("Chat History:")
    # Use pprint to avoid truncation in notebook output
import pprint
pprint.pprint(history.get_messages())
# Out:
# Chat History:
# [{'content': 'Sure! Let’s break down “cost-effectiveness analysis” (often '
#              'called CEA) in simple terms, using a real-life analogy:\n'
#              '\n'
#              '**Imagine you’re at the grocery store.**  \n'
#              'You want to buy apples, but you also want to get the best deal '
#              'for your money. There are two bags of apples:\n'
#              '\n'
#              '- **Bag A:** Costs $5 and has 5 apples.\n'
#              '- **Bag B:** Costs $8 and has 10 apples.\n'
#              '\n'
#              'Which one is the better buy?  \n'
#              'You divide the price by the number of apples:\n'
#              '\n'
#              '- Bag A: $5 ÷ 5 = $1 per apple\n'
#              '- Bag B: $8 ÷ 10 = $0.80 per apple\n'
#              '\n'
#              'So, **Bag B gives you more apples for your money**; it’s more '
#              '“cost-effective.”\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### How does this relate to healthcare?\n'
#              '\n'
#              'In healthcare, we have to decide which treatments or medicines '
#              'to use. But treatments cost money, and some work better than '
#              'others. **Cost-effectiveness analysis** helps us figure out '
#              'which treatment gives us the best “health result” for the money '
#              'spent.\n'
#              '\n'
#              '- **Cost:** How much does the treatment cost? (Like the price of '
#              'the apple bag)\n'
#              '- **Effectiveness:** How much does it help people get better? '
#              '(Like the number of apples)\n'
#              '\n'
#              '**CEA compares the extra cost of one treatment to the extra '
#              'benefit it provides,** just like comparing the price per apple.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### Example in Healthcare\n'
#              '\n'
#              'Suppose there are two medicines for treating a disease:\n'
#              '\n'
#              '- **Medicine X:** Costs $1,000 and helps 50 out of 100 people '
#              'recover.\n'
#              '- **Medicine Y:** Costs $2,000 and helps 70 out of 100 people '
#              'recover.\n'
#              '\n'
#              'A cost-effectiveness analysis would help us see if the extra '
#              'money for Medicine Y is worth the extra people it helps.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### In summary:\n'
#              '**Cost-effectiveness analysis is like comparing prices at the '
#              'store,** but instead of apples, we compare medical treatments to '
#              'see which one gives us more health for our money. It helps '
#              'doctors, hospitals, and governments decide how to spend '
#              'healthcare money wisely!',
#   'role': 'assistant'},
#  {'content': 'Can you explain that in more detail?', 'role': 'user'},
#  {'content': 'Absolutely! Let’s go into more detail, still using simple '
#              'language and analogies.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### What is Cost-Effectiveness Analysis (CEA)?\n'
#              '\n'
#              '**Cost-effectiveness analysis** is a way to compare different '
#              'healthcare treatments or programs to see which one gives us the '
#              'most health benefit for the money we spend. It helps people who '
#              'make decisions in healthcare (like governments, insurance '
#              'companies, or hospitals) decide where to spend their limited '
#              'budget.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### A Simple Analogy: Fixing Your Car\n'
#              '\n'
#              'Imagine you have a car with a broken part. You go to two '
#              'mechanics:\n'
#              '\n'
#              '- **Mechanic A** says they can fix your car for $100, and it '
#              'will last for 1 year.\n'
#              '- **Mechanic B** says they can fix your car for $150, and it '
#              'will last for 3 years.\n'
#              '\n'
#              'Which repair should you choose?\n'
#              '\n'
#              'You want to know not just the price, but also how long the fix '
#              'will last. So you compare the cost for each year your car will '
#              'run:\n'
#              '\n'
#              '- Mechanic A: $100 ÷ 1 year = $100 per year\n'
#              '- Mechanic B: $150 ÷ 3 years = $50 per year\n'
#              '\n'
#              '**Mechanic B is more cost-effective** because you get more '
#              '“working car years” for each dollar spent.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### Applying This to Healthcare\n'
#              '\n'
#              'In healthcare, instead of “car years,” we are often looking at '
#              'things like:\n'
#              '\n'
#              '- How many people get better?\n'
#              '- How many years of healthy life does a treatment add?\n'
#              '- How much does a treatment reduce pain or symptoms?\n'
#              '\n'
#              'Let’s use a made-up example with a medicine for high blood '
#              'pressure:\n'
#              '\n'
#              '- **Medicine A**: Costs $500 per year, and keeps 1 out of 10 '
#              'people from having a heart attack.\n'
#              '- **Medicine B**: Costs $1,000 per year, and keeps 3 out of 10 '
#              'people from having a heart attack.\n'
#              '\n'
#              'Now let’s see what you get for your money:\n'
#              '\n'
#              '- Medicine A: $500 to prevent 1 heart attack.\n'
#              '- Medicine B: $1,000 to prevent 3 heart attacks ($333 per heart '
#              'attack prevented).\n'
#              '\n'
#              'So, **Medicine B is more cost-effective** because you spend less '
#              'per heart attack prevented, even though the medicine costs more '
#              'overall.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### What About “Quality of Life”?\n'
#              '\n'
#              'Sometimes treatments help people live longer, but sometimes they '
#              'also help people live better (less pain, more ability to do '
#              'things). In CEA, experts often use a measure called '
#              '“quality-adjusted life years” (QALYs). You can think of this as '
#              'combining both **how long** and **how well** people live.\n'
#              '\n'
#              '- If a treatment gives you 1 extra year of life in perfect '
#              'health, that’s 1 QALY.\n'
#              '- If it gives you 2 extra years, but only at half normal health, '
#              'that’s also 1 QALY (2 years × 0.5 quality).\n'
#              '\n'
#              'CEA often looks at **cost per QALY**—how much money does it take '
#              'to give someone one extra year of good-quality life?\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### Why Is This Important?\n'
#              '\n'
#              'Healthcare budgets are limited. There isn’t enough money to pay '
#              'for every possible treatment for every person. '
#              'Cost-effectiveness analysis helps decision makers:\n'
#              '\n'
#              '- **Prioritize** the treatments that do the most good for the '
#              'least money.\n'
#              '- **Avoid waste**—not spending a lot on treatments that don’t '
#              'help much.\n'
#              '- **Be fair**—so everyone gets the best possible care for the '
#              'resources available.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### In Summary\n'
#              '\n'
#              'Think of CEA as **shopping for the best value**—not just the '
#              'lowest price, but the best results for each dollar spent.  \n'
#              'It helps make sure healthcare money is spent in a way that helps '
#              'the most people, in the best ways possible.\n'
#              '\n'
#              'If you want a more specific example or have questions about '
#              'certain words, let me know!',
#   'role': 'assistant'},
#  {'content': "I didn't understand the detectives analogy. Please elaborate.",
#   'role': 'user'},
#  {'content': 'No problem! It looks like there was a mix-up—I haven’t used a '
#              'detectives analogy yet. But since you’re curious, let’s build '
#              'one together to explain cost-effectiveness analysis (CEA) using '
#              'detectives:\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### Cost-Effectiveness Analysis: The Detective Analogy\n'
#              '\n'
#              '**Imagine you are the chief of police in a city.**  \n'
#              'You have a mystery to solve, but your budget is limited. You can '
#              'hire detectives to investigate. You have two detective agencies '
#              'to choose from:\n'
#              '\n'
#              '- **Agency A:** Charges $500 and solves 3 out of 10 cases.\n'
#              '- **Agency B:** Charges $800 and solves 6 out of 10 cases.\n'
#              '\n'
#              'You want to spend your money wisely and solve as many cases as '
#              'possible.  \n'
#              'So, you ask: “For each dollar I spend, how many cases get '
#              'solved?”\n'
#              '\n'
#              '#### Breaking it Down:\n'
#              '- **Agency A:** $500 ÷ 3 cases = about $167 per case solved.\n'
#              '- **Agency B:** $800 ÷ 6 cases = about $133 per case solved.\n'
#              '\n'
#              '**Agency B is more cost-effective** because you spend less money '
#              'for each case solved—even though they cost more overall.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### How Does This Relate to Healthcare?\n'
#              '\n'
#              'In healthcare, instead of detectives solving cases, we have '
#              'treatments helping people get better.\n'
#              '\n'
#              '- **The money you spend (the budget) = the cost of the '
#              'detectives (or treatments).**\n'
#              '- **The cases solved = the number of people helped or lives '
#              'saved.**\n'
#              '\n'
#              'Cost-effectiveness analysis helps you figure out which treatment '
#              '(or detective agency) gives you the most benefit for your '
#              'money.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### Why Is This Useful?\n'
#              '\n'
#              'Just like the police chief wants to solve the most cases with '
#              'the budget, healthcare decision-makers want to help the most '
#              'patients with the money they have.  \n'
#              'Cost-effectiveness analysis is the tool they use to make those '
#              'smart, efficient choices.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '**In summary:**  \n'
#              'Cost-effectiveness analysis is like hiring the detective agency '
#              'that solves the most mysteries for every dollar you spend, so '
#              'your city is safer without wasting money. In healthcare, it’s '
#              'about choosing the treatments that help the most people for the '
#              'money available.\n'
#              '\n'
#              'Let me know if you’d like another example or more detail!',
#   'role': 'assistant'},
#  {'content': 'GUtilities are cardinal values that represent the strength of '
#              'an\n'
#              'individual’s preferences for specific health-related outcomes.\n'
#              'GMeasuring health utilities involves two main steps: defining a\n'
#              'set of health states of interest, and valuing those health\n'
#              'states. There are direct or indirect methods of utility\n'
#              'valuation.\n'
#              'GThe methods that have been used to collect data on utilities\n'
#              'include t he standar dgamble approach, the time trade-off\n'
#              'approach and the visual analogue approach.\n'
#              'GThe main indir ect met hods of utility measur ement ar e: the '
#              'use\n'
#              'of generic preference instruments (EQ-5D, SF-6D and HUI);\n'
#              'the use of disease-specific preference measures; and\n'
#              'mapping from a disease-specific health-related quality\n'
#              'of life instrument to a generic instrument.\n'
#              'GGeneric pr eference-based measures are increasingly being used\n'
#              'in cost–utility anal yses of pharmaceutical and other\n'
#              'healthcare interventions. In the UK, the National Institute\n'
#              'for Health and Clinical Excellence has specified the EQ-5D as '
#              'itspreferred method of utility measurement.\n'
#              'GUtilities have been used as the preference weights (quality\n'
#              'levels) within the quality-adjusted life-year model – '
#              'anincreasingly popular outcome measure used in pharmaceutical\n'
#              'market access decision-making.\n'
#              '1What is...? series Second edition\n'
#              'For further titles in the series, visit:\n'
#              'www.whatisseries.co.uk\n'
#              'Keith Tolley MPhil\n'
#              'Health Economist and\n'
#              'Director , Tolley Health\n'
#              'Economics LtdWhat are \n'
#              'health utilities?Supported by sanofi-aventis\n'
#              'Date of preparation: April 2009 NPR09/1103Health '
#              'economicsInhealth economics, utilities are cardinal\n'
#              'values that reflect an individual’s preferences\n'
#              'for different health outcomes. They aremeasured on an interval '
#              'scale with zero\n'
#              'reflecting states of health equivalent to death\n'
#              'and one reflecting perfect health. In healtheconomics, utilities '
#              'are typically combinedwith survival estimates and aggregated '
#              'acrossindividuals to generate quality-adjusted life-years '
#              '(QALYs) for use in cost–utility analysesof healt hcare '
#              'interventions (Box 1) .\n'
#              '1,2\n'
#              'Utility measurement consists of two main\n'
#              'components. These are:\n'
#              'GThe definition and description of a set of\n'
#              'health states of interest\n'
#              'GThe valuation of those health states (that is,\n'
#              'measur ement of t he strengthof pr eference\n'
#              'for each health state).\n'
#              'These com ponents can be applied in tw o\n'
#              'broad ways.3\n'
#              'GDirect measurement of utilities can be\n'
#              'performed for discrete condition-specific\n'
#              'healt hstates.\n'
#              'GIndir ect measurement of utilities can\n'
#              'be performed by applying utilityalgorit hms t ogeneric or '
#              'disease-specific\n'
#              'preference-based questionnaires, or bymapping from a '
#              'disease-specific health-\n'
#              'related quality of life (HRQoL) instrument\n'
#              'onto the utility algorithm of a genericinstrument such as the '
#              'EQ-5D (EuroQol\n'
#              'five dimension).\n'
#              'Direct measurement\n'
#              'methods\n'
#              'There are several pertinent issues to consider\n'
#              'in the use of direct measurement approaches,\n'
#              'three of which are discussed below.\n'
#              'GWhat are the relevant health dimensions?\n'
#              'GWhat utility v aluation method should be\n'
#              'used?\n'
#              'GWhose preferences should be measured?\n'
#              'What ar ethe relevant healt h\n'
#              'dimensions?\n'
#              'It is im portant that the relevant\n'
#              'dimensions and le vels of healt hare\n'
#              'assessed. If these dimensions and levels donot correspond to '
#              'patient outcomes, it willnot be possible t odetect differences '
#              'even if\n'
#              'suchdifferences exist. \n'
#              'Within the context of utility\n'
#              'measurement, \n'
#              'health dimensions are\n'
#              'referred to as attributes. Examples of\n'
#              'health attributes include: physical, social\n'
#              'and cognitive function; psychological well-being; sym ptoms; and '
#              'pain. These ar e\n'
#              'incorporated into a health state description\n'
#              '(sometimes referred to as a ‘vignette’) forthe particular '
#              'disease or condition ofinterest; for example, epileptic '
#              'seizurefrequency health state descriptions, orvisual im pairment '
#              'severity health state\n'
#              'descriptions.\n'
#              'The descriptions should ideally be based\n'
#              'on dir ect patient experience, alt hough in t he\n'
#              'interest of speed and feasibility many utility\n'
#              'studies have used clinicians or other healthprofessionals as '
#              'proxies backed by literatureevidence. The descriptions should '
#              'notcontain more than about five to nineattributes. Research '
#              'indicates that this is thelimit t othe amount of information '
#              'that\n'
#              'humans can simult aneousl yprocess.\n'
#              '4What are health utilities?\n'
#              '2What are\n'
#              'health utilities?\n'
#              'Date of pr eparation: April 2009 NPR09/1103Box 1. '
#              'Quality-adjusted life-years\n'
#              '(QALYs) in practice\n'
#              'Let us assume that ther earetwo tr eatments\n'
#              'for an illness. Both tr eatments extend the\n'
#              'life expectancy of an individual by eight\n'
#              'years. However, treatment A results in theindividual surviving '
#              'the years in full health(usually r epresented by a utility score '
#              'of 1 on\n'
#              'acardinal scale), while treatment B results in\n'
#              'the individual surviving the years in a healthstate with a '
#              'utility scor eof 0.5. T reatment A\n'
#              'has led to a gain in QAL Ys of 8 (8 x 1), while\n'
#              'treatment B has led to a gain in QALYs of 4\n'
#              '(8 x 0.5).3What are\n'
#              'health utilities?\n'
#              'Care should also be exercised to minimise\n'
#              'context effects in health state descriptions.\n'
#              'There may be labelling effects; for example,\n'
#              'the use of the term anaemia/fatigue could be\n'
#              'perceived and valued differently depending\n'
#              'onwhether or not it is labelled in the context\n'
#              'of cancer.\n'
#              'What utility valuation method\n'
#              'should be used?\n'
#              'There are a number of valuation methods \n'
#              'that have been used empirically in studies.These include '
#              'standard gamble (SG), timetrade-off (TTO), rating scales, '
#              'equivalencetechnique, ratio scaling and person trade-off.The f '
#              'irst three are the most frequently used in\n'
#              'direct measurement studies and so are the\n'
#              'focus here.\n'
#              'Standard gamble\n'
#              'The SG approach is the classic method of\n'
#              'measuring preferences in economics under conditions of uncer '
#              'tainty ,and w as\n'
#              'first presented by von Neumann and\n'
#              'Morgenstern.\n'
#              '5SG utilities ar efully\n'
#              'consis tent wit hexpect ed utility t heory \n'
#              'and the axioms of rational individual\n'
#              'behaviour.\n'
#              'The SG appr oach involves presenting\n'
#              'individuals wit hachoice between two\n'
#              'alternatives: a health state that is certain (for\n'
#              'example, frequent migraine attacks) and agamble wit hone better '
#              '(for example, full\n'
#              'health) and one worse (for example, death)\n'
#              'outcome possible. Respondents are askedwhat pr obability of t he '
#              'bett er out come\n'
#              'would make them indifferent between\n'
#              'remaining in the described (migraine)health state for certain or '
#              'going for the riskyoption. Hence, if they are indifferentbetween '
#              'the migraine state and a gamblewitha0.8 probability of the '
#              'better outcome\n'
#              '(but 0.2 pr obability of t he worse outcome),\n'
#              '0.8 represents the utility of the migraine\n'
#              'healt hstate.\n'
#              'The utilities generated by the SG approach\n'
#              'are dependent on the risk behaviour of theindividuals surveyed. '
#              'In general, individualbehaviour is risk averse, meaning '
#              'respondentswill tend towards the certain outcome ratherthan the '
#              'gamble (producing higher utilitiesfor the health state than the '
#              'risk-seeking\n'
#              'beha viour).\n'
#              '6Time trade-off\n'
#              'The TTO approach involves asking subjects to\n'
#              'consider the relative amounts of time (for\n'
#              'example, number of life-years) they would be\n'
#              'willing to sacrifice to avoid a certain poorer\n'
#              'health state (for example, frequent\n'
#              'migraines). Assuming a scenario of ten years\n'
#              'with frequent migraines, the respondent maybe indifferent '
#              'between this state and a shorter\n'
#              'lifetime of seven years, resulting in an\n'
#              'estimated utility for the frequent migrainehealth state of 0.7 '
#              '(seven years divided by tenyears).\n'
#              'Utilities generated by the TTO method\n'
#              'essentially represent cardinal ‘values’ basedon value theory '
#              'rather than expected utility\n'
#              'theory (the basis of SG). The importance of\n'
#              'this is that TTO assumes risk neutrality as a\n'
#              'choice is made under conditions of certainty\n'
#              '(that is, there are no risks); therefore, if\n'
#              'individuals are indeed risk averse, the utilityfor the same '
#              'health state generated by SG isexpect ed tobe higher t han t he '
#              'value\n'
#              'generated by TTO.\n'
#              'Apractical issue in TT Ostudies is the\n'
#              'choice of lif etime dur ation f or TT Ostudies.\n'
#              'Areview found this varied between one\n'
#              'month and 30 years.\n'
#              '7The impact this has on\n'
#              'the utility estimates generated is\n'
#              'inconclusiv e.\n'
#              'Rating scale (visual analogue scale)\n'
#              'The r ating scale (or visual analogue scale\n'
#              '[VAS]) is based on psychometric theory. It\n'
#              'consists of a single line with anchorsrepresenting bes tpossible '
#              'healt hand deat h\n'
#              '(or some alternative). Respondents are asked\n'
#              'to place each health state on the line suchthat the intervals '
#              'between the placementsreflect their perceived differences '
#              'between thehealth states. \n'
#              'The V AS approach generate values rather\n'
#              'than utilities, and has t he least grounding in\n'
#              'economic theory as it involves neither any\n'
#              'element of c hoice nor individual decision-\n'
#              'making under uncertainty. However, Parkin\n'
#              'and Devlin have argued that the VAS hasimportant advantages '
#              '(versus SG and TTO) inempirical performance.\n'
#              '8\n'
#              'Due to its simplicity the VAS is often used\n'
#              'as a ‘warm-up’ to a TTO or SG exercise, as itallows the '
#              'respondent to become familiar\n'
#              'withcomparing the health states.\n'
#              'Date of preparation: April 2009 NPR09/1103Comparing the '
#              'valuation methods\n'
#              'Ingeneral, health economists support the use\n'
#              'ofchoice-based methods (SG or TTO) over\n'
#              'the VAS. However, the SG approach is\n'
#              'relatively time-consuming and people often\n'
#              'have difficulty understanding the concept of\n'
#              'probabilities. For many, the TTO represents a\n'
#              'reliable and practical middle way, althoughthe trade-off concept '
#              'could still be difficult\n'
#              'for many people to understand.\n'
#              'The choice of method matters as the\n'
#              'differences in theoretical grounding andvaluation approach can '
#              'lead to differences inutility estimates. A review of utilities '
#              'across995 chronic and acute health states found astrong tendency '
#              'for VAS to yield the lowest,\n'
#              'TTO the middle and SG the highest utility\n'
#              'values for the same health states.\n'
#              '9Direct\n'
#              'measur ement studies may be particularly\n'
#              'useful for valuing specific side-effects or\n'
#              'modes of drug administration (where thereare obvious and '
#              'plausible differences in QoLimpact).\n'
#              '10,11\n'
#              'Whose pr eferences should be\n'
#              'measur ed?\n'
#              'The valuation of preferences using SG, TTO or\n'
#              'VAS can be performed by either the public orpatients (or ,in the '
#              'case of young children,\n'
#              'proxies such as caregivers/parents).\n'
#              'GThe primar yreason for selecting\n'
#              'patients is that they are the people who\n'
#              'experience t he im pact of the disease and\n'
#              'treatment, so it is their preferences that\n'
#              'should be considered of most importance. Ifpatients ar eused, t '
#              'heycan be ask ed tovalue\n'
#              'ahypothetical health state or their own\n'
#              'health state. While it is more challenging torecruit patients '
#              'with the specific healthstates of interest, utilities obtained '
#              'throughhypothetical scenarios may not be validpredictors of '
#              'preferences associated with\n'
#              'actual experienced healt hstates.\n'
#              '12\n'
#              'GThe rationale for measuring the\n'
#              'preferences of t he general public for\n'
#              'hypothetical health states is that in a\n'
#              'publicly funded healthcare system, it issociety’s resources that '
#              'are being allocatedand so it is the views of the '
#              'generalpopulation that are most relevant.\n'
#              '1\n'
#              'The question of whose preference to\n'
#              'measur eisimportant because there is some\n'
#              'evidence t hat utilities differ betweendifferent population '
#              'groups. In general,\n'
#              'patient values for hypothetical health states\n'
#              'that are likely to be worse than their current\n'
#              'health state tend to be higher than those\n'
#              'from the general public. This may be related\n'
#              'topatients’ coping mechanisms when\n'
#              'addressing ill health.13\n'
#              'There are situations in which proxies are\n'
#              'necessary; for example, when measuring\n'
#              'young children’s preferences. In a study\n'
#              'conducted in a mixed UK population sample,parents/caregivers '
#              'produced higher utilitiesthan the general public in the context '
#              'ofLennox–Gastaut syndrome – a severe form ofchildhood epilepsy.\n'
#              '11Increasingly, the proxy\n'
#              'values of clinicians or other healthcare\n'
#              'professionals are recognised as not\n'
#              'representing a valid or reliable source for\n'
#              'utilities.14\n'
#              'Afurther issue is the minimum sample size\n'
#              'for public- or patient-based valuation studies.No rules have '
#              'been set for this and manyutility s tudies ha vebeen conduct ed '
#              'on v ery\n'
#              'small sam ple sizes.\n'
#              '15In general, a rule of\n'
#              'thumb is t hat, t obe considered reliable,\n'
#              'population-based s tudies should ha vea\n'
#              'minimum of 100 respondents representing a\n'
#              'cross section of society. Achieving sufficientlylarge sample '
#              'sizes becomes more difficult\n'
#              'withpatient-based valuation studies,\n'
#              'especiall yif based on patients experiencing\n'
#              'the actual health state. Also, there is a limit tothe number of '
#              'healt hstates that each\n'
#              'respondent can cope with – a rule of thumb is\n'
#              'amaximum of ten but fewer if possible, due\n'
#              'tointervie wfatigue (t his also depends on t he\n'
#              'skills of the interviewer and the\n'
#              'administration techniques used).\n'
#              'Indirect measurement\n'
#              'methods\n'
#              'Generic utility ins truments\n'
#              'By far the most well-known indirect method\n'
#              'is thegeneric utility ins trument, whereby a\n'
#              'set of non-disease-specific health states, based\n'
#              'on a combination of general attributes, havebeen valued by a '
#              'general public sample.\n'
#              'Three instruments in common use today\n'
#              'are the EQ-5D, the SF-6D (Short Form sixdimension) and the HUI '
#              '(Health UtilitiesIndex), alt hough there are other instruments\n'
#              'used g loball y(for example, QWB [Quality of\n'
#              '4What are\n'
#              'health utilities?\n'
#              'Date of pr eparation: April 2009 NPR09/1103Well-Being] and 15D '
#              '[15 dimension]).1\n'
#              'For each instrument, the public values a\n'
#              'limited number of health states and a scoring\n'
#              'algorithm is developed using econometric\n'
#              'modelling (EQ-5D and SF-6D) or a\n'
#              'multiplicative multi-attribute utility function\n'
#              '(HUI) to predict utilities for other health\n'
#              'states not directly valued. Patients with anyhealth condition '
#              'then complete a simple\n'
#              'questionnaire which defines the generic\n'
#              'health state they are in, and the appropriateutility from the '
#              'scoring algorithm is applied.\n'
#              'The instruments differ in the specific\n'
#              'general attributes used for their descriptivesystems and in the '
#              'method of valuationapplied – t he EQ-5D has been valued using\n'
#              'TTO, while the SF-6D is a derivative of the SF-\n'
#              '36 (Short Form 36 item) and has been valued\n'
#              'using SG. The HUI has tw oclassification\n'
#              'systems (HUI2 and HUI3) which differ in\n'
#              'attributes but were also measured by SG. All,however, have been '
#              'valued by large generalpublic sam ples.\n'
#              'Generic utility ins truments address some\n'
#              'of the pr actical dif ficulties of conducting\n'
#              'direct TT Oor SG ex ercises. A lar ge amount of\n'
#              'research effort by separate EQ-5D, SF-6D and\n'
#              'HUI research teams has gone into thedevelopment of standard, '
#              'off-the-shelf\n'
#              'questionnaires that can be completed in a few\n'
#              'minut es by patients in randomised, clinical\n'
#              'trials or observational studies. The secondadvantage of generic '
#              'instruments from a\n'
#              'decision-maker’s perspective is that they\n'
#              'generate general health state utilities that canbe used t '
#              'ocompareQALYs gained f or\n'
#              'interventions across patient groups and\n'
#              'diseases to aid broad health service resource-allocation '
#              'decisions.\n'
#              'However, there are a number of potential\n'
#              'limitations with generic preference-basedinstruments.\n'
#              'GTheymaylack sensitivity in specific disease\n'
#              'contexts.\n'
#              'GTheyaredifficult to apply to acute\n'
#              'conditions (for example, an asthma\n'
#              'exacerbation) or when assessing smallerdifferences in utility '
#              '(for example, thoseassociated with mode of drugadministration or '
#              'specific drug-related side-effects).\n'
#              'GTher eis evidence of ceiling effects with the\n'
#              'EQ-5D and f loor ef fects with the SF-6D.16GThey generate '
#              'different estimates for the\n'
#              'same condition, which is related to their\n'
#              'differences in valuation methods and\n'
#              'scoring algorithms. For example, a study of\n'
#              'the QoL of hearing-impaired people found\n'
#              'mean utility scores were similar using the\n'
#              'EQ-5D and SF-6D (0.77 and 0.79\n'
#              'respectively), but much lower using theHUI3 (0.56).\n'
#              '17\n'
#              'Disease-specific utility instruments\n'
#              'In response to sensitivity issues with the\n'
#              'generic measures, preference-based disease-specific measures are '
#              'beginning to bedeveloped. The principle here is that '
#              'theutilities att ached to a disease-specific HRQoL\n'
#              'instrument are generated in the same way as\n'
#              'with a generic instrument. Examples of\n'
#              'preference-based scoring systems generated\n'
#              'this way include the International Prostate\n'
#              'Symptom Score (IPSS) for benign prostatichyperplasia,\n'
#              '18the International Index of\n'
#              'Erectile F unction (IIEE)19and t he Cambridg e\n'
#              'Pulmonar yHypertension Outcome Review\n'
#              '(CAMPHOR).20All ha vebeen v alued using\n'
#              'TTOmethodology .\n'
#              'The construction of these instruments is\n'
#              'promising, but they are still at a relativelyearlystage of '
#              'development, so their value for\n'
#              'decision-making has y et to be realised. They\n'
#              'have the advantage of generating potentially\n'
#              'sensitive disease-specific utilities throughapplication of a v '
#              'alidat edHRQoL instrument\n'
#              'in a clinical trial. However, the main practical\n'
#              'limitation is the amount of research effortrequired togenerate '
#              'the utility scales; hence, a\n'
#              'limited number of diseases have been covered\n'
#              'so far.\n'
#              'Mapping utilities\n'
#              'Avariant to developing a disease-specific\n'
#              'utility measur eis to map the descriptions\n'
#              'from a disease-specif ic QoL instrument onto\n'
#              'the utility algorithm of a generic instrument.\n'
#              'This met hod is of ten used when a g eneric\n'
#              'instrument is not available, but a suitable\n'
#              'disease-specific QoL instrument has beenincluded in clinical '
#              'trials.\n'
#              'While it is possible to perform mapping\n'
#              'based on clinician judgement, the rigour ofthis approach can be '
#              'enhanced by using anempirical database containing both the\n'
#              'HRQoL ins trument and a generic instrument\n'
#              '5What are\n'
#              'health utilities?\n'
#              'Date of preparation: April 2009 NPR09/11036such as the EQ-5D '
#              'administered to the same\n'
#              'patient to generate a mapping function. Evenso, caution is '
#              'needed in interpreting mappingfunctions deriv ed this w ay,as a '
#              'r angeof\n'
#              'estimation methods have been applied in\n'
#              'previous s tudies with varying levels of\n'
#              'statistical r obus tness.\n'
#              '21\n'
#              'Use of utilities in decision-\n'
#              'making\n'
#              'As the use of economic evaluation for\n'
#              'pharmaceutical market access decision-making incr eases g '
#              'lobally, QALYs and, hence,\n'
#              'utility assessments are being used as a key\n'
#              'outcome measure within those evaluations.\n'
#              'In the UK, t he calculation of QAL Ys is a\n'
#              'central part of the reference case for\n'
#              'economic evaluations of pharmaceuticalssubmitted to the National '
#              'Institute for Healthand Clinical Excellence (NICE).\n'
#              '14,22NICE has a\n'
#              'hierarchy of methods for the derivation ofutilities, wit hthe '
#              'use of the EQ-5D within\n'
#              'clinical trials being t he pr eferred method.\n'
#              'However, if it is not available, utilities can be\n'
#              'deriv ed using t he TT Ovaluation method in\n'
#              'community-based respondent samples (Figure\n'
#              '1).\n'
#              '14Other bodies in the UK (for example, the\n'
#              'Scottish Medicines Consortium [SMC]) andother countries are less '
#              'prescriptive and allowavariety of methods to be used as long as\n'
#              'they are performed robustly and the utilityvalues generated for '
#              'the health states appear\n'
#              'plausible.References\n'
#              '1.Drummond MF ,Sculpher MJ, Torrance GW, O’Brien\n'
#              'BJ, Stoddart GL. Methods for the Economic Evaluation of\n'
#              'HealthCare Programmes, 3rdedn. Oxford: Oxford\n'
#              'University Press, 2005.\n'
#              '2. Torrance GW. Measurement of health state utilities\n'
#              'for economic appr aisal. JHealt hEcon 1986; 5:1–30.\n'
#              '3. Szende A, Schaefer C. A taxonomy of health utilityassessment '
#              'methods and the role for uncertaintyanalysis. \n'
#              'Eur J Health Econ 2006; 7:147–151.\n'
#              '4. Miller G A. The magical number se ven plus or minus\n'
#              'two: some limits on our capacity for processing\n'
#              'information. Psychol Rev 1956; 63:81–97.\n'
#              '5. von Neumann J, Morgenstern O. Theory of Games and\n'
#              'Economic Behavior 3rd edn. New York: John Wiley, 1953.\n'
#              '6. Torrance GW, Furlong W, Feeny D, Boyle M. Multi-\n'
#              'attribute preference functions. Health Utilities Index.\n'
#              'Phar macoeconomics 1995; 7:503–520.\n'
#              '7.Arnesen T, Trommald M. Are QALYs based on time\n'
#              'trade-off comparable?—A systematic review of TTOmethodologies. \n'
#              'Health Econ 2005; 14:39–53.\n'
#              '8. Parkin D, Devlin N. Is there a case for using visual\n'
#              'analogue scale valuations in cost-utility analysis? Health\n'
#              'Econ 2006; 15:653–664.\n'
#              '9. Morimot oT,Fukui T. Utilities measured by rating\n'
#              'scale, time trade-off, and standard gamble: review and\n'
#              'reference for health care professionals. JEpidemiol 2002;\n'
#              '12:160–178.\n'
#              '10. Osborne RH, de Abreu Lourenco R, Dalton A et al.\n'
#              'Quality of life related to oral versus subcutaneous iron\n'
#              'chelation: a time trade-off study. Value Health 2007; 10:\n'
#              '451–456.\n'
#              '11. Yi Y, Verdian L, Oyee J, Tolley K, Heyes A. Elicitingutility '
#              'scor es for healt hstates associat ed wit h\n'
#              'Lennox–Gastaut syndrome. 2008; \n'
#              '11:A606.\n'
#              '12. Jansen SJ, S tiggelbout AM, Wakker PP et al. Unstable\n'
#              'preferences: a shif tin valuation or an effect of the\n'
#              'elicitation procedure? Med Decis Making 2000; 20:\n'
#              '62–71.\n'
#              '13. Ubel PA, Loewenstein G, Jepson C. Whose quality oflife? A '
#              'commentary exploring discrepancies betweenhealth state '
#              'evaluations of patients and the generalpublic. \n'
#              'Qual Lif eRes2003; 12:599–607 .\n'
#              '14. National Institute for Health and Clinical Excellence.\n'
#              'Guide t othe methods of technology appraisal (June 2008).\n'
#              'www .nice.or g.uk/media/B52/A7/T AMet hodsGuideUpdat\n'
#              'edJune2008.pdf (last accessed 9 December 2008)\n'
#              '15. Tufts Medical Center. Cost-Effectiveness Analysis\n'
#              'Registry (CEA). https://research.tufts-\n'
#              'nemc.org/cear/default.aspx (last accessed 9 December2008)16. '
#              'FerreiraPL, F erreira LN, Pereira LN. How consistent\n'
#              'are health utility values? \n'
#              'Qual Life Res 2008; 17:\n'
#              '1031–1042.\n'
#              '17.Barton GR, Bankart J, Davis AC. A comparison of theWhat are\n'
#              'health utilities?\n'
#              'Date of pr eparation: April 2009 NPR09/1103\n'
#              'Trial A 1vs C 1\n'
#              'No EQ-5D data, but there is a\n'
#              'validated HRQoL questionnaire\n'
#              'in the trialEQ-5D in trial*\n'
#              'Mapping to EQ-5D\n'
#              'Direct valuationsNo EQ-5D in the trial, but\n'
#              'there is a disease-specific HRQoL\n'
#              'questionnaire and relevant\n'
#              'EQ-5D data available out of\n'
#              'the trial\n'
#              'Discrete health states based\n'
#              'on HRQoL instrument and\n'
#              'valued in UK population\n'
#              'sample using TTO\n'
#              '*Or other validated instrument with similar properties if EQ-5D '
#              'not appropriate, or use HUI2 in children\n'
#              ' HRQoL: health-related quality of life; TTO: time '
#              'trade-offFigure 1. NICE hierarchy of utility methods147quality '
#              'of life of hearing-impaired people as estimated\n'
#              'bythree different utility measures. Int J Audiol 2005; 44:\n'
#              '157–163.\n'
#              '18. Kok ET, McDonnell J, Stolk EA, Stoevelaar HJ,\n'
#              'Busschbach JJ. The valuation of the International\n'
#              'Prostate Symptom Score (IPSS) for use in economic\n'
#              'evaluations. Eur Urol 2002; 42:491–497.\n'
#              '19. Stolk EA, Busschbach JJ. Validity and feasibility of theuse '
#              'of condition-specific outcome measures in economic\n'
#              'evaluation. \n'
#              'Qual Life Res 2003; 12:363–371.\n'
#              '20. McKenna SP, Ratcliffe J, Meads DM, Brazier JE.Development '
#              'and validation of a preference based\n'
#              'measure derived from the Cambridge Pulmonary\n'
#              'Hypertension Outcome Review (CAMPHOR) for use in\n'
#              'cost utility analyses. Health Qual Life Outcomes 2008; 6:\n'
#              '65.\n'
#              '21. Brazier J, Ratcliffe J, Tsuchiya A, Salomon J. Measuring\n'
#              'and Valuing Health Benefits for Economic Evaluation .\n'
#              'Oxford: Oxford University Press, 2007.\n'
#              '22. Brazier J. Valuing health states for use in cost-\n'
#              'effectiveness analysis. Pharmacoeconomics 2008; 26:\n'
#              '769–779.What are\n'
#              'health utilities?\n'
#              'Date of preparation: April 2009 NPR09/1103Suppor ted by '
#              'sanofi-aventis What are\n'
#              'health utilities?\n'
#              'Published by Hayw ard Medical\n'
#              'Communications, a division of\n'
#              'Hayw ard Group Ltd.\n'
#              'Copyright © 2009 Hayward \n'
#              'Group Ltd.All rights reserved.\n'
#              '8What is...? series\n'
#              'First edition published 2001\n'
#              'Author: Stavros Petrou\n'
#              'This publication, along with\n'
#              'the others in the series ,i s\n'
#              'available on the internet atwww .whatisseries .co.uk\n'
#              'The data, opinions and statements\n'
#              'appearing in the article(s) herein\n'
#              'are those of the contributor(s)concerned. Accordingly, the\n'
#              'sponsor and publisher, and their\n'
#              'respective employees, officers\n'
#              'and agents, accept no liability\n'
#              'for the consequences of any suchinaccurate or misleading data,\n'
#              'opinion or statement.\n'
#              'Date of preparation: April 2009 NPR09/1103',
#   'role': 'user'},
#  {'content': 'Absolutely! I’ll explain the statement in simple, layman’s terms '
#              'using analogies and examples.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '## What Are Health Utilities?\n'
#              '\n'
#              '**Imagine you’re rating how good or bad different health '
#              'situations are, a bit like giving a movie a score out of '
#              '10.**  \n'
#              'But here, instead of 1 to 10, we use a scale from 0 to 1:\n'
#              '- **1** means you feel as good as possible (perfect health).\n'
#              '- **0** means the worst possible health (equivalent to being '
#              'dead).\n'
#              '\n'
#              'These scores are called **utilities**. They help us put a number '
#              'on how “good” or “bad” a particular health state is, based on '
#              'what people prefer.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '## Step 1: Define Health States\n'
#              '\n'
#              'First, you have to describe different health situations (“health '
#              'states”).  \n'
#              'For example:\n'
#              '- Living with mild pain\n'
#              '- Needing help to walk\n'
#              '- Having trouble breathing\n'
#              '\n'
#              'Each health state is like describing a different “scene” in a '
#              'movie about health. You need to be specific, like: “Can walk, '
#              'but with pain; needs help with daily tasks; feels tired most '
#              'days.”\n'
#              '\n'
#              '---\n'
#              '\n'
#              '## Step 2: Value Those Health States\n'
#              '\n'
#              'Now, you ask people: “How good or bad does this health state '
#              'feel to you, compared to perfect health or death?”  \n'
#              'There are two main ways to get these scores:\n'
#              '\n'
#              '### A) **Direct Methods** (asking people directly)\n'
#              'Examples:\n'
#              '- **Standard Gamble (SG):** Like asking, “Would you rather live '
#              'with this health problem, or take a risky chance: maybe you get '
#              'perfect health, or maybe you die?” You adjust the chance until '
#              'the person can’t decide which is better.\n'
#              '- **Time Trade-Off (TTO):** “Would you rather live 10 years with '
#              'this health problem, or fewer years in perfect health?” You see '
#              'how many years in perfect health is “worth” 10 years with the '
#              'health problem.\n'
#              '- **Visual Analogue Scale (VAS):** Give people a line from 0 '
#              '(worst) to 100 (best), and ask them to mark how they feel about '
#              'the health state.\n'
#              '\n'
#              '### B) **Indirect Methods** (using questionnaires)\n'
#              'There are special surveys (like EQ-5D, SF-6D, HUI) that ask '
#              'about everyday health problems (walking, pain, mood). People '
#              'fill them out, and their answers are used to look up a utility '
#              'score from a big database.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '## Why Do We Do This?\n'
#              '\n'
#              '**Utilities are used in something called “Quality-Adjusted Life '
#              'Years” (QALYs).**\n'
#              '\n'
#              'Let’s use an example:\n'
#              '- If a treatment gives you 8 years of life in perfect health, '
#              'that’s 8 QALYs (8 × 1).\n'
#              '- If you get 8 years with a health problem scored at 0.5, that’s '
#              '4 QALYs (8 × 0.5).\n'
#              '\n'
#              'Comparing QALYs helps doctors and governments decide which '
#              'treatments give the best “bang for the buck” (best health for '
#              'the money).\n'
#              '\n'
#              '---\n'
#              '\n'
#              '## Why Is This Important?\n'
#              '\n'
#              'Imagine you’re running a hospital with limited money. Utilities '
#              'and QALYs help you decide:\n'
#              '- Should we pay for a new drug that gives people slightly better '
#              'health, or use that money for something else?\n'
#              '- Which treatment makes people feel better, not just live '
#              'longer?\n'
#              '\n'
#              'It’s like using ratings to decide which movies to buy for a '
#              'school—if you only have money for a few, you want those that '
#              'make everyone happiest.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '## In Summary\n'
#              '\n'
#              '- **Health utilities** are like scores for different health '
#              'situations, based on how people feel about them.\n'
#              '- We get these scores by directly asking people, or by using '
#              'special surveys.\n'
#              '- These scores help us compare treatments and use healthcare '
#              'money in ways that help people the most.\n'
#              '\n'
#              'If you want a specific example or more details on any method, '
#              'just ask!',
#   'role': 'assistant'},
#  {'content': "I didn't understand the scene in a movie analogy. Please "
#              'elaborate.',
#   'role': 'user'},
#  {'content': 'Of course! Let’s look at the “scene in a movie” analogy in more '
#              'detail, step by step.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### Step 1: Imagine a Movie About Health\n'
#              '\n'
#              'Think about your favorite movie. Every movie is made up of '
#              'different scenes, and each scene shows the characters in a '
#              'certain situation—maybe they’re happy, sad, in danger, or '
#              'relaxing.\n'
#              '\n'
#              'Now, **imagine a movie where each scene shows a person in a '
#              'different health situation**. For example:\n'
#              '- In one scene, the character is running and playing with '
#              'friends (perfect health).\n'
#              '- In another scene, the character is walking slowly because of '
#              'knee pain.\n'
#              '- In another, the character needs help getting dressed and feels '
#              'tired all the time.\n'
#              '\n'
#              'Each of these scenes is like a different “health state” in real '
#              'life.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### Step 2: Rating the Scenes\n'
#              '\n'
#              'Suppose you’re a movie critic, and your job is to rate each '
#              'scene based on how enjoyable or good you think it is for the '
#              'character.  \n'
#              '- The scene where the character is running and playing might get '
#              'a **10 out of 10** (or 1 on the health utility scale).\n'
#              '- The scene where the character can walk but is in pain might '
#              'get a **5 out of 10** (or 0.5 on the health utility scale).\n'
#              '- The scene where the character needs help with everything, '
#              'feels tired, and can’t do what they want might get a **2 out of '
#              '10** (or 0.2 on the health utility scale).\n'
#              '\n'
#              '**These ratings are like “utilities” in health economics.**  \n'
#              'They show how good or bad each health state (scene) feels to '
#              'you.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### Step 3: Why Describe Health States Like Scenes?\n'
#              '\n'
#              'Just like a movie scene includes details (location, what '
#              'characters are doing, how they feel), a health state description '
#              'includes details like:\n'
#              '- Can the person walk?\n'
#              '- Do they feel pain?\n'
#              '- Can they take care of themselves?\n'
#              '- Are they happy or sad?\n'
#              '\n'
#              '**Describing health states like scenes helps people imagine what '
#              'it would be like to live in that situation and give it a '
#              'score.**\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### Step 4: Why Use These Scores?\n'
#              '\n'
#              '- We use these scores to compare treatments, just like you might '
#              'compare different scenes or movies.\n'
#              '- If a treatment helps people move from a “bad scene” to a '
#              '“better scene,” we can measure how much better it makes their '
#              'lives.\n'
#              '\n'
#              '---\n'
#              '\n'
#              '**In summary:**  \n'
#              'Each “scene” in the movie analogy is a different health '
#              'situation someone might experience. We “rate” these scenes to '
#              'figure out how good or bad each one is. These ratings help '
#              'doctors and decision-makers compare different treatments in a '
#              'fair and understandable way.\n'
#              '\n'
#              'If you’d like, I can give you a concrete example using a made-up '
#              'movie and specific scenes!',
#   'role': 'assistant'}]

# %%
    # If you want to clear the chat history:
history.clear_history()
print("Chat History:")
pprint.pprint(history.get_messages())
# Out:
# Chat History:
# []

# %%
# File processing example
file_path = r"C:\Users\HananIrfan\Downloads\AMVUTTRA-CM_Core Cost-Effectiveness Analysis_TechnicalReport_VF_23April2025.docx"
text = process_file(file_path)
if text:
        # Add the file's extracted text as a user message
        history.add_message("user", text)
        resp, cb = generate_response(
            text, profession, max_words, api_key,
            engine, temperature, max_tokens, history
        )
        print("From file:", resp)
else:
        print("No text extracted from file.")
# Out:
# From file: Certainly! The statement you provided is a detailed technical table of contents and executive summary from a health economic evaluation (HEOR) report about the cost-effectiveness of **vutrisiran** compared to other treatments for **transthyretin amyloid cardiomyopathy (ATTR-CM)**.
#
# As a layperson with some HEOR knowledge, let me break this down in plain English, using analogies and everyday examples:
#
# ---
#
# ### 1. **What is this report about?**
# Imagine you’re part of a government or insurance company deciding whether to pay for a new medicine. You have to decide: “Is this new medicine worth the money, compared to what we already have, or just regular care?”
#
# This report is like a big, detailed **comparison shopping guide** for a new drug called **vutrisiran**, used to treat a rare heart condition called ATTR-CM. The goal is to see if this drug gives enough extra health benefit to justify its cost.
#
# ---
#
# ### 2. **What is a cost-effectiveness model?**
# Think of this as a **giant calculator** or a **complex spreadsheet**. It looks at all the costs (like the price of the drug, hospital visits, doctor appointments) and all the benefits (like longer life and better quality of life) for patients who use vutrisiran, versus those who use other medicines (like tafamidis) or just get regular care.
#
# ---
#
# ### 3. **What are they comparing?**
# - **Vutrisiran by itself**
# - **Vutrisiran plus another drug (tafamidis)**
# - **Tafamidis by itself**
# - **Best supportive care** (just helping the patient manage symptoms, not using these specific drugs)
#
# ---
#
# ### 4. **How do they measure “is it worth it?”**
# #### **Key terms:**
# - **QALY (Quality-Adjusted Life Year):** Imagine life like a score out of 1. A year in perfect health = 1 QALY. A year in less-than-perfect health is less than 1. If a treatment gives you more good-quality years, it increases your QALYs.
# - **ICER (Incremental Cost-Effectiveness Ratio):** This is like the “price per extra point” you get. How much extra money does it cost to gain 1 more QALY with the new drug, compared to the old one?
# - **Willingness-to-Pay Threshold:** This is the “budget limit” — say, £30,000 per QALY. If a new drug costs more than this per extra QALY, it might not be considered “worth it.”
#
# #### **Analogy:**
# If you’re buying a car, you might look at “cost per mile” or “cost per year of use.” Here, it’s “cost per year of good-quality life gained.”
#
# ---
#
# ### 5. **How does the model work?**
# Imagine following a group of patients as they move through different “health states” (from mild to severe illness, or death), like a **board game**. Each turn (every 3 months), patients can stay where they are, get better, get worse, or die. The model tracks how many people are in each state, how much it costs, and what their quality of life is.
#
# #### **Health States:**
# - **NYHA Classes I-IV:** These are like “levels” of heart failure, from mild (I) to very severe (IV).
# - Patients can also have events like hospital stays or serious side effects, which affect costs and quality of life.
#
# ---
#
# ### 6. **What did the model find?**
# - **Vutrisiran gives more good-quality life (QALYs) and longer life compared to tafamidis or just supportive care.**
# - **BUT** it is **much more expensive**. The cost per extra QALY is way above the usual “budget limit” (£2 million per QALY for one comparison, when the limit is £30,000 per QALY).
# - **Most of the extra cost is simply the high price of the drug.**
#
# #### **Analogy:**
# Imagine a new car that gets you to your destination 10 minutes faster, but costs 100 times more than your current car. Is it worth it?
#
# ---
#
# ### 7. **What about uncertainty?**
# Just like weather forecasts have “chance of rain,” these models check how results might change if you tweak the numbers (like drug price, survival rates, etc.). This is called a **sensitivity analysis**.
#
# - The results didn’t change much when they tested different assumptions — meaning the model is fairly robust.
# - But even in the best scenarios, the cost is much higher than the usual threshold.
#
# ---
#
# ### 8. **Why so expensive?**
# Most of the high cost comes from the drug itself, not from hospital stays or other care. Even if patients live longer and better, the price tag for the drug is so high that it doesn’t look like a good deal for the health system.
#
# ---
#
# ### 9. **What’s the conclusion?**
# The new drug is effective — it helps patients live longer and better. But at its current price, it’s not considered “cost-effective” compared to the alternatives, unless the price comes down **a lot**.
#
# ---
#
# ### 10. **Why is all this important?**
# Health systems have limited money (like any household or business). They want to spend it on treatments that give the most “bang for the buck.” If a new treatment costs a lot more, but only gives a little more benefit, it might not be funded.
#
# ---
#
# ### 11. **What are all those tables and figures?**
# - **Tables** list all the numbers and calculations behind the scenes: drug prices, how many patients have side effects, how quality of life is measured, etc.
# - **Figures** are charts and graphs showing how patients move through health states, or how costs and benefits stack up over time.
#
# ---
#
# ### **In summary:**
# This report is a very detailed, scientific way for decision makers to check if a new, expensive medicine for a rare heart disease gives enough extra benefit to justify its price. Like a car buyer’s guide, it compares the pros, cons, and costs, so healthcare systems can decide if they should “buy” (fund) it or not.
#
# ---
#
# **If you need any term explained in simpler terms or want an analogy for a specific table or section, just ask!**
